# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pokemon_data = pd.read_csv('Datasets/Pokemon.csv')

# %%
pokemon_data.head()
# Out:
#                     Name Type 1  Type 2  Total Point  Health Point  \
# 0              Bulbasaur  Grass  Poison          318            45
# 1                Ivysaur  Grass  Poison          405            60
# 2               Venusaur  Grass  Poison          525            80
# 3  VenusaurMega Venusaur  Grass  Poison          625            80
# 4             Charmander   Fire     NaN          309            39
#
#    Attack Point  Defense Point  Sp. Atk Point  Sp. Def Point  Speed Point  \
# 0            49             49             65             65           45
# 1            62             63             80             80           60
# 2            82             83            100            100           80
# 3           100            123            122            120           80
# 4            52             43             60             50           65
#
#    Generation
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
sns.lmplot(x = 'Total Point', 
          y = 'Health Point', data = pokemon_data)

# %%
sns.lmplot(x = 'Total Point', 
          y = 'Health Point', data = pokemon_data,
          x_estimator = np.mean)

# %%
pokemon_data['Type 1'].value_counts()
# Out:
# Bug         11
# Poison      10
# Normal      10
# Grass        7
# Fire         7
# Water        4
# Ground       3
# Electric     2
# Fairy        2
# Name: Type 1, dtype: int64

# %%
sns.lmplot(x = 'Total Point', 
          y = 'Health Point', data = pokemon_data,
          x_estimator = np.mean, col = 'Type 1', col_wrap = 4)

# %%
pokemon_data['Type 2'].value_counts()
# Out:
# Poison    13
# Flying    11
# Fairy      2
# Ground     2
# Grass      2
# Dragon     1
# Name: Type 2, dtype: int64

# %%
sns.lmplot(x = 'Total Point', 
          y = 'Health Point', data = pokemon_data,
          x_estimator = np.mean, col = 'Type 1', col_wrap = 3, hue = 'Type 2')

# %%
sns.countplot(x = pokemon_data['Type 1'], hue = pokemon_data['Type 2'])
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='count'>

# %%
sns.regplot(x = 'Attack Point',
           y = 'Defense Point', data = pokemon_data)
# Out:
# <AxesSubplot:xlabel='Attack Point', ylabel='Defense Point'>

# %%
sns.jointplot(x = 'Attack Point',
           y = 'Defense Point', data = pokemon_data,
             kind = 'reg')

# %%
sns.pairplot(data = pokemon_data, 
             x_vars = ['Attack Point', 'Defense Point', 'Speed Point'],
             y_vars = 'Total Point',
             kind = 'reg')

# %% [markdown]
# # Categorical ANalysis

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# swarmplot, stripplot, boxplot, violinplot,barplot, catplot

# %%
sns.set(style='whitegrid',
        color_codes = True)

# %%
plt.subplots(figsize = (12,6))
sns.stripplot(x = 'day', y ='tip',data = tips, jitter = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.subplots(figsize = (12,6))
sns.swarmplot(x = 'day', y ='tip',data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.subplots(figsize = (12,6))
sns.swarmplot(x = 'day', y ='tip',data = tips, hue = 'size')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
(tips['size'].value_counts())
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
(tips['size'].value_counts()).index = range(len(tips['size'].value_counts()))
print(tips[tips['size'] == 2]['size'].sum())
print(tips[tips['size'] == 1]['size'].sum())
print(tips[tips['size'] == 3]['size'].sum())
print(tips[tips['size'] == 4]['size'].sum())
print(tips[tips['size'] == 5]['size'].sum())
print(tips[tips['size'] == 6]['size'].sum())
# Out:
# 312
# 4
# 114
# 148
# 25
# 24

# %%
sns.countplot(tips['size'])
# Out:
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.boxplot(x = 'day', y ='tip',data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x = 'day', y ='tip',data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.catplot(x = 'day', y ='tip',data = tips, kind = 'strip')

# %% [markdown]
# # EDA on Titanic dataset

# %%
# Variable	Definition	   Key
# survival	Survival	   0 = No, 1 = Yes
# pclass	    Ticket class   1 = 1st, 2 = 2nd, 3 = 3rd
# sex	        Sex	
# Age	        Age in years	
# sibsp	    # of siblings / spouses aboard the Titanic	
# parch	    # of parents / children aboard the Titanic	
# ticket	    Ticket number	
# fare	    Passenger fare	
# cabin	    Cabin number	
# embarked    Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %%
# Importing library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading datset
ttnc = sns.load_dataset('titanic')

# %%
ttnc['age'] = ttnc['age'].fillna(0)
ttnc
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   0.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.set(style='whitegrid',
        color_codes = True)
plt.rcParams['figure.figsize'] = [15,5]
plt.rcParams['figure.dpi'] = 100

# %%
ttnc.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
ttnc.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   23.799293    0.523008    0.381594   32.204208
# std      0.486592    0.836071   17.596074    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    6.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   24.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
ttnc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
ttnc.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False  False  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
ttnc.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(data = ttnc.isnull(), cmap = 'Reds', cbar = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5fdde997ae74> in <module>
# ----> 1 sns.heatmap(data = ttnc.isnull(), cmap = 'Reds', cbar = True)
#
# NameError: name 'sns' is not defined

# %%
cormat = ttnc.corr()
cormat
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481  0.010539 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.361353  0.083081  0.018443 -0.549500
# age         0.010539 -0.361353  1.000000 -0.184664 -0.048786  0.135516
# sibsp      -0.035322  0.083081 -0.184664  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.048786  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.135516  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.120022 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.030880 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.120022  0.030880
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(data= cormat, annot = True, square = True, cmap = 'Reds', cbar = True, fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
cnv, ax = plt.subplots(3,3, figsize = (20,20))
sns.countplot('survived', data = ttnc, ax = ax[0][0])
sns.countplot('pclass', data = ttnc, ax = ax[0][1])
sns.countplot('embarked', data = ttnc, ax = ax[0][2])
sns.countplot('sex', data = ttnc, ax = ax[1][0])
sns.countplot('sibsp', data = ttnc, ax = ax[1][1])
sns.countplot('parch', data = ttnc, ax = ax[1][2])
sns.countplot('alone', data = ttnc, ax = ax[2][0])
sns.distplot(ttnc['fare'], ax = ax[2][1], kde = False, bins = 80)
sns.distplot(ttnc['age'], ax = ax[2][2], kde = False)
# Out:
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
cnv, ax = plt.subplots(figsize = (20,20))
sns.distplot(ttnc['fare'], kde = False, bins = 80)
# Out:
# <AxesSubplot:xlabel='fare'>

# %% [markdown]
# # Analysis on survived columns

# %%
ttnc['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
sns.countplot('survived', data = ttnc)
# Out:
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
ttnc['survived'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ttnc['survived'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
ttnc['survived'].value_counts().plot.pie(autopct = '%1.2f%%')
# Out:
# <AxesSubplot:ylabel='survived'>

# %% [markdown]
# # EDA on PAssenger Class

# %%
ttnc.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ttnc['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
ttnc.groupby(['pclass', 'survived'])['survived'].count()
# Out:
# pclass  survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: survived, dtype: int64

# %%
sns.countplot('pclass', data = ttnc)
# Out:
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot('pclass', data = ttnc, hue = 'survived')
# Out:
# C:\Users\Mister AGYAAT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
ttnc['pclass'].value_counts().plot.pie(autopct = '%1.2f%%')
# Out:
# <AxesSubplot:ylabel='pclass'>

# %%
# Categorical plot - survivael rate/probability based on class
sns.catplot(x = 'pclass', y = 'survived', data = ttnc, kind = 'bar', hue = 'sex')

# %%
sns.catplot(x = 'pclass', y = 'survived', data = ttnc, kind = 'bar', col = 'sex')

# %%
sns.catplot(x = 'pclass', y = 'survived', kind = 'point', data = ttnc)
