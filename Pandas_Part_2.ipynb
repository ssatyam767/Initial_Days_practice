# %%
# Addition and deletion
# Selction and indexing
# Iterating over dataframe
# Concate and merge
# Reshaping of data frame

# %%
import pandas as pd

# %%
inter_org = pd.read_csv('datasets/international_org.csv')
inter_org
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
# Add a column in rthe dataframe
inter_org['Founded on'] = 1950

# %%
inter_org
# Out:
#   Organization Name  Headquater  Founded on
# 0               FAO        Rome        1950
# 1               ICJ   The Hague        1950
# 2               IMF  Washington        1950
# 3            UNESCO       Paris        1950
# 4               UNO    New York        1950
# 5        World Bank  Washington        1950

# %%
inter_org['Founded on'][1] = 1948
inter_org
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-731d9906f3f8> in <module>
# ----> 1 inter_org['Founded on'][1] = 1948
#       2 inter_org
#
# NameError: name 'inter_org' is not defined

# %%
movie_rate = pd.read_csv('datasets/imdb_rating.csv')
movie_rate
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# Deletion of a column
del movie_rate['duration']

# %%
movie_rate
# Out:
#    star_rating                                          title      genre
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama

# %%
# Adding a row
movie_rate.loc[10] = [9.5, 'ASUR', 'Crime']
movie_rate
# Out:
#     star_rating                                          title      genre
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.5                                           ASUR      Crime

# %%
movie_rate.loc[-1] = [5.5, 'ABC', 'Crime']
movie_rate
# Out:
#      star_rating                                          title      genre
#  0           9.3                       The Shawshank Redemption      Crime
#  1           9.2                                  The Godfather      Crime
#  2           9.1                         The Godfather: Part II      Crime
#  3           9.0                                The Dark Knight     Action
#  4           8.9                                   Pulp Fiction      Crime
#  5           8.9                                   12 Angry Men      Drama
#  6           8.9                 The Good, the Bad and the Ugly    Western
#  7           8.9  The Lord of the Rings: The Return of the King  Adventure
#  8           8.9                               Schindler's List  Biography
#  9           8.9                                     Fight Club      Drama
#  10          9.5                                           ASUR      Crime
# ...

# %%
movie_rate.index = movie_rate.index+1
movie_rate = movie_rate.sort_index()

# %%
movie_rate
# Out:
#     star_rating                                          title      genre
# 0           5.5                                            ABC      Crime
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           9.0                                The Dark Knight     Action
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          8.9                                     Fight Club      Drama
# 11          9.5                                           ASUR      Crime

# %%
movie_rate.loc[4] = [7.0, 'MNO', 'Drama']

# %%
movie_rate
# Out:
#     star_rating                                          title      genre
# 0           5.5                                            ABC      Crime
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           7.0                                            MNO      Drama
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          8.9                                     Fight Club      Drama
# 11          9.5                                           ASUR      Crime

# %%
# print(movie_rate.loc[list(movie_rate['star_rating']).index(min(list(movie_rate['star_rating'])))]['title'])
# movie_rate.at[0, 'title'] = 'XYZ'
# movie_rate
# Out:
# XYZ
#     star_rating                                          title      genre
# 0           5.5                                            XYZ      Crime
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           7.0                                            MNO      Drama
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          8.9                                     Fight Club      Drama
# 11          9.5                                           ASUR      Crime

# %%
movie_rate.loc[list(movie_rate['star_rating']).index(min(list(movie_rate['star_rating'])))] = [5.5, 'MNO', 'Crime']
movie_rate
# Out:
#     star_rating                                          title      genre
# 0           5.5                                            MNO      Crime
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           7.0                                            MNO      Drama
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          8.9                                     Fight Club      Drama
# 11          9.5                                           ASUR      Crime

# %%
# movie_rate.loc[movie_rate[movie_rate['star_rating'] == 8.9].index.values[2]] =
# Out:
# star_rating                               8.9
# title          The Good, the Bad and the Ugly
# genre                                 Western
# Name: 7, dtype: object

# %%
movie_rate.loc[movie_rate[movie_rate['title'] == '12 Angry Men'].index.values[0]] = [5.5, '12 Angry Men', 'Drama', 5]

# %%
movie_rate
# Out:
#     star_rating                                          title      genre    6
# 0           5.5                                            MNO      Crime  5.5
# 1           9.3                       The Shawshank Redemption      Crime  5.5
# 2           9.2                                  The Godfather      Crime  5.5
# 3           9.1                         The Godfather: Part II      Crime  5.5
# 4           7.0                                            MNO      Drama  5.5
# 5           8.9                                   Pulp Fiction      Crime  5.5
# 6           5.5                                   12 Angry Men      Drama  5.0
# 7           8.9                 The Good, the Bad and the Ugly    Western  5.5
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure  5.5
# 9           8.9                               Schindler's List  Biography  5.5
# 10          8.9                                     Fight Club      Drama  5.5
# ...

# %%
movie_rate.at[movie_rate[movie_rate['title'] == '12 Angry Men'].index.values[0], 'star_rating'] = 4.5

# %%
movie_rate
# Out:
#     star_rating                                          title      genre    6
# 0           5.5                                            MNO      Crime  5.5
# 1           9.3                       The Shawshank Redemption      Crime  5.5
# 2           9.2                                  The Godfather      Crime  5.5
# 3           9.1                         The Godfather: Part II      Crime  5.5
# 4           7.0                                            MNO      Drama  5.5
# 5           8.9                                   Pulp Fiction      Crime  5.5
# 6           4.5                                   12 Angry Men      Drama  5.0
# 7           8.9                 The Good, the Bad and the Ugly    Western  5.5
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure  5.5
# 9           8.9                               Schindler's List  Biography  5.5
# 10          8.9                                     Fight Club      Drama  5.5
# ...

# %%
# Deleting a row - drop() - returns a new dataframe
movie_rate_1 = movie_rate.drop(movie_rate.index[[0,4]])
movie_rate_1
# Out:
#     star_rating                                          title      genre    6
# 1           9.3                       The Shawshank Redemption      Crime  5.5
# 2           9.2                                  The Godfather      Crime  5.5
# 3           9.1                         The Godfather: Part II      Crime  5.5
# 5           8.9                                   Pulp Fiction      Crime  5.5
# 6           4.5                                   12 Angry Men      Drama  5.0
# 7           8.9                 The Good, the Bad and the Ugly    Western  5.5
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure  5.5
# 9           8.9                               Schindler's List  Biography  5.5
# 10          8.9                                     Fight Club      Drama  5.5
# 11          9.5                                           ASUR      Crime  5.5

# %%
id_x = ['mov_1', 'mov_2', 'mov_3', 'mov_4', 'mov_5', 'mov_6', 'mov_7', 'mov_8', 'mov_9', 'mov_10']

# %%
movie_rate_1.index = id_x
movie_rate_1
# Out:
#         star_rating                                          title      genre  \
# mov_1           9.3                       The Shawshank Redemption      Crime
# mov_2           9.2                                  The Godfather      Crime
# mov_3           9.1                         The Godfather: Part II      Crime
# mov_4           8.9                                   Pulp Fiction      Crime
# mov_5           4.5                                   12 Angry Men      Drama
# mov_6           8.9                 The Good, the Bad and the Ugly    Western
# mov_7           8.9  The Lord of the Rings: The Return of the King  Adventure
# mov_8           8.9                               Schindler's List  Biography
# mov_9           8.9                                     Fight Club      Drama
# mov_10          9.5                                           ASUR      Crime
#
#           6
# mov_1   5.5
# mov_2   5.5
# mov_3   5.5
# mov_4   5.5
# mov_5   5.0
# mov_6   5.5
# mov_7   5.5
# ...

# %%
movie_rate_1 = movie_rate_1.reset_index()
movie_rate_1
# Out:
#     index  star_rating                                          title  \
# 0   mov_1          9.3                       The Shawshank Redemption
# 1   mov_2          9.2                                  The Godfather
# 2   mov_3          9.1                         The Godfather: Part II
# 3   mov_4          8.9                                   Pulp Fiction
# 4   mov_5          4.5                                   12 Angry Men
# 5   mov_6          8.9                 The Good, the Bad and the Ugly
# 6   mov_7          8.9  The Lord of the Rings: The Return of the King
# 7   mov_8          8.9                               Schindler's List
# 8   mov_9          8.9                                     Fight Club
# 9  mov_10          9.5                                           ASUR
#
#        genre    6
# 0      Crime  5.5
# 1      Crime  5.5
# 2      Crime  5.5
# 3      Crime  5.5
# 4      Drama  5.0
# 5    Western  5.5
# 6  Adventure  5.5
# 7  Biography  5.5
# 8      Drama  5.5
# ...

# %%
movie_rate_1 = movie_rate_1.drop(columns = ['index', 6])
movie_rate_1
# Out:
#    star_rating                                          title      genre
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          8.9                                   Pulp Fiction      Crime
# 4          4.5                                   12 Angry Men      Drama
# 5          8.9                 The Good, the Bad and the Ugly    Western
# 6          8.9  The Lord of the Rings: The Return of the King  Adventure
# 7          8.9                               Schindler's List  Biography
# 8          8.9                                     Fight Club      Drama
# 9          9.5                                           ASUR      Crime

# %% [markdown]
# # Selection and indexing

# %%
citi_ride = pd.read_csv('datasets/citibike_tripdata.csv')
citi_ride.shape
# Out:
# (32428, 10)

# %%
citi_ride.head(8)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
#
#       start station name  end station id end station name  bikeid  \
# 0             Harborside            3199     Newport Pkwy   33558
# 1               Grand St            3185        City Hall   33593
# 2        McGinley Square            3193     Lincoln Park   29217
# ...

# %%
citi_ride.tail(8)
# Out:
#        tripduration            starttime             stoptime  \
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32421           255  2018-05-30 13:45:38  2018-05-30 13:49:54
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32420              3183       Exchange Place            3211       Newark Ave
# 32421              3183       Exchange Place            3213   Van Vorst Park
# 32422              3202         Newport PATH            3199     Newport Pkwy
# 32423              3184          Paulus Hook            3279      Dixon Mills
# ...

# %%
citi_ride['start station id'].head(5)
# Out:
# 0    3639
# 1    3681
# 2    3194
# 3    3185
# 4    3207
# Name: start station id, dtype: int64

# %%
citi_ride[['start station id', 'end station id']].head(5)
# Out:
#    start station id  end station id
# 0              3639            3199
# 1              3681            3185
# 2              3194            3193
# 3              3185            3186
# 4              3207            3195

# %%
citi_ride.at[1, 'start station id']
# Out:
# 3681

# %%
citi_ride.at[1, 'start station id'] = 32000
citi_ride[['start station id', 'end station id']].head(5)
# Out:
#    start station id  end station id
# 0              3639            3199
# 1             32000            3185
# 2              3194            3193
# 3              3185            3186
# 4              3207            3195

# %%
new_citi_ride = citi_ride[:10]

# %%
new_citi_ride
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53             32000
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# ...

# %%
ride_id = ['ride_'+str(i) for i in range(1,11)]

# %%
ride_id
# Out:
# ['ride_1',
#  'ride_2',
#  'ride_3',
#  'ride_4',
#  'ride_5',
#  'ride_6',
#  'ride_7',
#  'ride_8',
#  'ride_9',
#  'ride_10']

# %%
new_citi_ride.index = ride_id

# %%
new_citi_ride
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_2              32000               Grand St            3185
# ...

# %%
new_citi_ride.loc['ride_3']
# Out:
# tripduration                                               232
# starttime                                  2018-05-01 01:31:29
# stoptime                                   2018-05-01 01:35:22
# start station id                                          3194
# start station name                             McGinley Square
# end station id                                            3193
# end station name                                  Lincoln Park
# bikeid                                                   29217
# name_localizedValue    FREE Bonus Month with Annual Membership
# usertype                                            Subscriber
# Name: ride_3, dtype: object

# %%
new_citi_ride.loc['ride_1':'ride_3']
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#         start station id start station name  end station id end station name  \
# ride_1              3639         Harborside            3199     Newport Pkwy
# ride_2             32000           Grand St            3185        City Hall
# ride_3              3194    McGinley Square            3193     Lincoln Park
#
#         bikeid                      name_localizedValue    usertype
# ride_1   33558                        Annual Membership  Subscriber
# ride_2   33593                                  24 Hour    Customer
# ride_3   29217  FREE Bonus Month with Annual Membership  Subscriber

# %%
new_citi_ride.loc['ride_1':'ride_3', 'start station id':'end station name']
# Out:
#         start station id start station name  end station id end station name
# ride_1              3639         Harborside            3199     Newport Pkwy
# ride_2             32000           Grand St            3185        City Hall
# ride_3              3194    McGinley Square            3193     Lincoln Park

# %%
new_citi_ride[new_citi_ride['tripduration']>200]
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_2             32000               Grand St            3185
# ride_3              3194        McGinley Square            3193
# ride_5              3207            Oakland Ave            3195
# ride_7              3225  Baldwin at Montgomery            3186
# ride_8              3207            Oakland Ave            3185
# ...

# %%
new_citi_ride.loc[new_citi_ride['tripduration']>200, :'end station name':2]
# Out:
#         tripduration             stoptime     start station name  \
# ride_1           338  2018-05-01 00:10:25             Harborside
# ride_2          1482  2018-05-01 01:55:53               Grand St
# ride_3           232  2018-05-01 01:35:22        McGinley Square
# ride_5           303  2018-05-01 04:32:16            Oakland Ave
# ride_7           577  2018-05-01 05:15:23  Baldwin at Montgomery
# ride_8           830  2018-05-01 05:25:41            Oakland Ave
# ride_9           395  2018-05-01 05:18:42  Baldwin at Montgomery
#
#        end station name
# ride_1     Newport Pkwy
# ride_2        City Hall
# ride_3     Lincoln Park
# ride_5          Sip Ave
# ride_7    Grove St PATH
# ride_8        City Hall
# ride_9    Grove St PATH

# %%
new_citi_ride.loc[new_citi_ride['tripduration']>200,'start station id']
# Out:
# ride_1     3639
# ride_2    32000
# ride_3     3194
# ride_5     3207
# ride_7     3225
# ride_8     3207
# ride_9     3225
# Name: start station id, dtype: int64

# %%
new_citi_ride.iloc[5]
# Out:
# tripduration                           176
# starttime              2018-05-01 04:37:05
# stoptime               2018-05-01 04:40:01
# start station id                      3194
# start station name         McGinley Square
# end station id                        3195
# end station name                   Sip Ave
# bikeid                               29298
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: ride_6, dtype: object

# %%
new_citi_ride.iloc[1:5]
# Out:
#         tripduration            starttime             stoptime  \
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#         start station id start station name  end station id end station name  \
# ride_2             32000           Grand St            3185        City Hall
# ride_3              3194    McGinley Square            3193     Lincoln Park
# ride_4              3185          City Hall            3186    Grove St PATH
# ride_5              3207        Oakland Ave            3195          Sip Ave
#
#         bikeid                      name_localizedValue    usertype
# ride_2   33593                                  24 Hour    Customer
# ride_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
new_citi_ride.iloc[1:5, :6]
# Out:
#         tripduration            starttime             stoptime  \
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#         start station id start station name  end station id
# ride_2             32000           Grand St            3185
# ride_3              3194    McGinley Square            3193
# ride_4              3185          City Hall            3186
# ride_5              3207        Oakland Ave            3195

# %%
new_citi_ride.iloc[1:5, ::2]
# Out:
#         tripduration             stoptime start station name end station name  \
# ride_2          1482  2018-05-01 01:55:53           Grand St        City Hall
# ride_3           232  2018-05-01 01:35:22    McGinley Square     Lincoln Park
# ride_4           190  2018-05-01 02:06:40          City Hall    Grove St PATH
# ride_5           303  2018-05-01 04:32:16        Oakland Ave          Sip Ave
#
#                             name_localizedValue
# ride_2                                  24 Hour
# ride_3  FREE Bonus Month with Annual Membership
# ride_4                                  24 Hour
# ride_5                        Annual Membership

# %%
new_citi_ride.iloc[[0, 4, 6, 9], ::]
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_5               3207            Oakland Ave            3195
# ride_7               3225  Baldwin at Montgomery            3186
# ride_10              3206                Hilltop            3195
#
#         end station name  bikeid                   name_localizedValue  \
# ride_1      Newport Pkwy   33558                     Annual Membership
# ride_5           Sip Ave   15271                     Annual Membership
# ride_7     Grove St PATH   33619  Annual Membership from Citi Bike App
# ...

# %%
new_citi_ride[new_citi_ride['usertype']== 'Subscriber']
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_3               3194        McGinley Square            3193
# ride_5               3207            Oakland Ave            3195
# ride_6               3194        McGinley Square            3195
# ...

# %%
new_citi_ride[(new_citi_ride['usertype']== 'Subscriber') & (new_citi_ride['bikeid'] > 30000)]
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_7               3225  Baldwin at Montgomery            3186
# ride_8               3207            Oakland Ave            3185
# ride_10              3206                Hilltop            3195
#
#         end station name  bikeid                   name_localizedValue  \
# ride_1      Newport Pkwy   33558                     Annual Membership
# ride_7     Grove St PATH   33619  Annual Membership from Citi Bike App
# ride_8         City Hall   33624                     Annual Membership
# ...

# %%
new_citi_ride[(new_citi_ride['usertype']== 'Customer') | (new_citi_ride['bikeid'] < 30000)]
# Out:
#         tripduration            starttime             stoptime  \
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_2             32000               Grand St            3185
# ride_3              3194        McGinley Square            3193
# ride_4              3185              City Hall            3186
# ride_5              3207            Oakland Ave            3195
# ride_6              3194        McGinley Square            3195
# ride_9              3225  Baldwin at Montgomery            3186
#
# ...

# %%
new_citi_ride[new_citi_ride['usertype'] != 'Subscriber']
# Out:
#         tripduration            starttime             stoptime  \
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#         start station id start station name  end station id end station name  \
# ride_2             32000           Grand St            3185        City Hall
# ride_4              3185          City Hall            3186    Grove St PATH
#
#         bikeid name_localizedValue  usertype
# ride_2   33593             24 Hour  Customer
# ride_4   29662             24 Hour  Customer

# %%
new_citi_ride[~(new_citi_ride['usertype'] == 'Subscriber')]
# Out:
#         tripduration            starttime             stoptime  \
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#         start station id start station name  end station id end station name  \
# ride_2             32000           Grand St            3185        City Hall
# ride_4              3185          City Hall            3186    Grove St PATH
#
#         bikeid name_localizedValue  usertype
# ride_2   33593             24 Hour  Customer
# ride_4   29662             24 Hour  Customer

# %%
#Iterating iver dataframe
movie_rate
# Out:
#     star_rating                                          title      genre    6
# 0           5.5                                            MNO      Crime  5.5
# 1           9.3                       The Shawshank Redemption      Crime  5.5
# 2           9.2                                  The Godfather      Crime  5.5
# 3           9.1                         The Godfather: Part II      Crime  5.5
# 4           7.0                                            MNO      Drama  5.5
# 5           8.9                                   Pulp Fiction      Crime  5.5
# 6           4.5                                   12 Angry Men      Drama  5.0
# 7           8.9                 The Good, the Bad and the Ugly    Western  5.5
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure  5.5
# 9           8.9                               Schindler's List  Biography  5.5
# 10          8.9                                     Fight Club      Drama  5.5
# ...

# %%
for row in movie_rate.itertuples():
    print(row)
# Out:
# Pandas(Index=0, star_rating=5.5, title='MNO', genre='Crime', _4=5.5)
# Pandas(Index=1, star_rating=9.3, title='The Shawshank Redemption', genre='Crime', _4=5.5)
# Pandas(Index=2, star_rating=9.2, title='The Godfather', genre='Crime', _4=5.5)
# Pandas(Index=3, star_rating=9.1, title='The Godfather: Part II', genre='Crime', _4=5.5)
# Pandas(Index=4, star_rating=7.0, title='MNO', genre='Drama', _4=5.5)
# Pandas(Index=5, star_rating=8.9, title='Pulp Fiction', genre='Crime', _4=5.5)
# Pandas(Index=6, star_rating=4.5, title='12 Angry Men', genre='Drama', _4=5.0)
# Pandas(Index=7, star_rating=8.9, title='The Good, the Bad and the Ugly', genre='Western', _4=5.5)
# Pandas(Index=8, star_rating=8.9, title='The Lord of the Rings: The Return of the King', genre='Adventure', _4=5.5)
# Pandas(Index=9, star_rating=8.9, title="Schindler's List", genre='Biography', _4=5.5)
# Pandas(Index=10, star_rating=8.9, title='Fight Club', genre='Drama', _4=5.5)
# ...

# %%
for ind, row in movie_rate.iterrows():
    print(ind)
    print(row)
    print()
# Out:
# 0
# star_rating      5.5
# title            MNO
# genre          Crime
# 6                5.5
# Name: 0, dtype: object
#
# 1
# star_rating                         9.3
# title          The Shawshank Redemption
# genre                             Crime
# 6                                   5.5
# Name: 1, dtype: object
#
# 2
# star_rating              9.2
# title          The Godfather
# genre                  Crime
# 6                        5.5
# Name: 2, dtype: object
#
# 3
# star_rating                       9.1
# title          The Godfather: Part II
# genre                           Crime
# 6                                 5.5
# Name: 3, dtype: object
#
# 4
# star_rating        7
# title            MNO
# genre          Drama
# 6                5.5
# Name: 4, dtype: object
#
# 5
# star_rating             8.9
# title          Pulp Fiction
# genre                 Crime
# 6                       5.5
# Name: 5, dtype: object
#
# 6
# star_rating             4.5
# ...

# %%
for key,val in movie_rate.iteritems():
    print('key', key)
    print(val)
# Out:
# key star_rating
# 0     5.5
# 1     9.3
# 2     9.2
# 3     9.1
# 4     7.0
# 5     8.9
# 6     4.5
# 7     8.9
# 8     8.9
# 9     8.9
# 10    8.9
# 11    9.5
# Name: star_rating, dtype: float64
# key title
# 0                                               MNO
# 1                          The Shawshank Redemption
# 2                                     The Godfather
# 3                            The Godfather: Part II
# 4                                               MNO
# 5                                      Pulp Fiction
# 6                                      12 Angry Men
# 7                    The Good, the Bad and the Ugly
# 8     The Lord of the Rings: The Return of the King
# 9                                  Schindler's List
# 10                                       Fight Club
# 11                                             ASUR
# Name: title, dtype: object
# key genre
# 0         Crime
# 1         Crime
# 2         Crime
# 3         Crime
# 4         Drama
# ...

# %% [markdown]
# # Sorting a dataframe

# %%
unsort_movie_rate = pd.read_csv('datasets/unsorted_imdb_rating.csv')
unsort_movie_rate
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
unsort_movie_rate.index = [8,7,1,9,0,6,5,3,4,2]

# %%
unsort_movie_rate
# Out:
#    star_rating                                          title      genre  \
# 8          9.3                       The Shawshank Redemption      Crime
# 7          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 9          9.0                                The Dark Knight     Action
# 0          8.9                                   Pulp Fiction      Crime
# 6          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.3                               Schindler's List  Biography
# 2          8.1                                     Fight Club      Drama
#
#    duration
# 8       142
# 7       175
# 1       200
# 9       152
# 0       154
# 6        96
# 5       161
# 3       201
# 4       195
# 2       139

# %%
unsort_movie_rate.sort_index()
# Out:
#    star_rating                                          title      genre  \
# 0          8.9                                   Pulp Fiction      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 2          8.1                                     Fight Club      Drama
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.3                               Schindler's List  Biography
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 6          8.8                                   12 Angry Men      Drama
# 7          9.1                                  The Godfather      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.0                                The Dark Knight     Action
#
#    duration
# 0       154
# 1       200
# 2       139
# 3       201
# 4       195
# 5       161
# 6        96
# 7       175
# 8       142
# 9       152

# %%
unsort_movie_rate.sort_index(ascending = False)
# Out:
#    star_rating                                          title      genre  \
# 9          9.0                                The Dark Knight     Action
# 8          9.3                       The Shawshank Redemption      Crime
# 7          9.1                                  The Godfather      Crime
# 6          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 4          8.3                               Schindler's List  Biography
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 2          8.1                                     Fight Club      Drama
# 1          9.2                         The Godfather: Part II      Crime
# 0          8.9                                   Pulp Fiction      Crime
#
#    duration
# 9       152
# 8       142
# 7       175
# 6        96
# 5       161
# 4       195
# 3       201
# 2       139
# 1       200
# 0       154

# %%
unsort_movie_rate['genre'].sort_index()
# Out:
# 0        Crime
# 1        Crime
# 2        Drama
# 3    Adventure
# 4    Biography
# 5      Western
# 6        Drama
# 7        Crime
# 8        Crime
# 9       Action
# Name: genre, dtype: object

# %%
unsort_movie_rate.sort_values(by = 'title')
# Out:
#    star_rating                                          title      genre  \
# 6          8.8                                   12 Angry Men      Drama
# 2          8.1                                     Fight Club      Drama
# 0          8.9                                   Pulp Fiction      Crime
# 4          8.3                               Schindler's List  Biography
# 9          9.0                                The Dark Knight     Action
# 7          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 6        96
# 2       139
# 0       154
# 4       195
# 9       152
# 7       175
# 1       200
# 5       161
# 3       201
# 8       142

# %%
unsort_movie_rate
# Out:
#    star_rating                                          title      genre  \
# 8          9.3                       The Shawshank Redemption      Crime
# 7          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 9          9.0                                The Dark Knight     Action
# 0          8.9                                   Pulp Fiction      Crime
# 6          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.3                               Schindler's List  Biography
# 2          8.1                                     Fight Club      Drama
#
#    duration
# 8       142
# 7       175
# 1       200
# 9       152
# 0       154
# 6        96
# 5       161
# 3       201
# 4       195
# 2       139

# %%
unsort_movie_rate.sort_values(by = ['genre', 'star_rating'])
# Out:
#    star_rating                                          title      genre  \
# 9          9.0                                The Dark Knight     Action
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.3                               Schindler's List  Biography
# 0          8.9                                   Pulp Fiction      Crime
# 7          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 2          8.1                                     Fight Club      Drama
# 6          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
#
#    duration
# 9       152
# 3       201
# 4       195
# 0       154
# 7       175
# 1       200
# 8       142
# 2       139
# 6        96
# 5       161

# %%
s = unsort_movie_rate.style.set_properties(**{'text-align': 'center'})
s
# Out:
# <style  type="text/css" >
#     #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row0_col0 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row0_col1 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row0_col2 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row0_col3 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row1_col0 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row1_col1 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row1_col2 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row1_col3 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row2_col0 {
#             text-align:  center;
#         }    #T_dbda68c2_06c1_11eb_a8a9_241b7ad0ee80row2_col1 {
# ...
