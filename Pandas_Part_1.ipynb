# %%
import pandas as pd
import numpy as np

# %%
# Series
# Data Frame

# !pip install pandas

# %%
# Creating a series from alist
lst = ['UP', 'MP', 'AP', 'TN', 'KA', 'TL']
pd.Series(lst)
# Out:
# 0    UP
# 1    MP
# 2    AP
# 3    TN
# 4    KA
# 5    TL
# dtype: object

# %%
ser4 = pd.Series(lst, index = list('abcdef'))

# %%
# creating a series from an array
ser = pd.Series(np.arange(25, 30), index = ['a', 'b', 'c', 'a', 'd'])
print(ser['a'])
# Out:
# a    25
# a    28
# dtype: int64

# %%
# Creating a series from dictionary
d = {1:100.20, 2:10, 3:10+20j, 4:'Python'}
ser1 = pd.Series(d)
ser1
# Out:
# 1       100.2
# 2          10
# 3    (10+20j)
# 4      Python
# dtype: object

# %%
ser2 = pd.Series(d, index = [1, 2, 3, 4, 5, 6] )
ser2.index = list('abcdef')
print(ser2[3])
print(ser2['d'])
# Out:
# Python
# Python

# %%
ser3 = pd.Series(d, index = ['1', '2', '3', '4', '5', '6'] )

# %%
print(ser2['d'])
print(ser2[3])
# Out:
# Python
# Python

# %%
# print(ser4)
print(ser4['b':'d'])
print(ser4[1:4])
# Out:
# b    MP
# c    AP
# d    TN
# dtype: object
# b    MP
# c    AP
# d    TN
# dtype: object

# %%
ser4.index = [1,2,3,4,5,6]
print(ser4)
# print(ser4[0])
# Out:
# 1    UP
# 2    MP
# 3    AP
# 4    TN
# 5    KA
# 6    TL
# dtype: object

# %%
states_lst = ['UP', 'MP', 'AP', 'TN', 'KA', 'TL']
capital_lst = ['LKO', 'BHP', 'AMT', 'CHN', 'BLR', 'HYD']

ser1 = pd.Series(capital_lst, index = states_lst)
print(ser1['MP'])
ser1['MP':'TN']
print(ser1[1:4])
# Out:
# 1    BHP
# 2    AMT
# 3    CHN
# dtype: object

# %% [markdown]
# # dataFrame

# %%
states_lst = ['UP', 'MP', 'AP', 'TN', 'KA', 'TL', 'KL']
capital_lst = ['LKO', 'BHP', 'AMT', 'CHN', 'BLR', 'HYD']
# pd.DataFrame(capital_lst, index = [states_lst], columns=['Capitals'])

# %%
# Creating a data frame with state and capital column
pd.DataFrame(zip(states_lst, capital_lst), columns=['States', 'Capitals'], index = ['st'+str(i) for i in range(1, 7)])
# Out:
#     States Capitals
# st1     UP      LKO
# st2     MP      BHP
# st3     AP      AMT
# st4     TN      CHN
# st5     KA      BLR
# st6     TL      HYD

# %%
['st'+str(i) for i in range(1, 7)]
# Out:
# ['st1', 'st2', 'st3', 'st4', 'st5', 'st6']

# %%
df = pd.read_csv('datasets/weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# print(df['day'][0])
# print(df['temperature'].max())
# print(df['temperature'].mean())
# print(df.shape)
# print(df.columns)

print(df.head(2))
print(df.tail())
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# accessing a coluns
# df.day
# print(df['day'])

# %%
pd.read_csv('/Users/vigneshkarthick/Desktop/LB_DSC_NOV_01_WKND/datasets/imdb_rating.csv')
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# Creating dataframe from excel file
df = pd.read_excel('datasets/football_worldcup.xlsx', 'Sheet 1')
df
# Out:
#    Year       Country    Winner   Runners-Up  GoalsScored  MatchesPlayed
# 0  1990         Italy  Germany     Argentina          115             52
# 1  1994           USA    Brazil        Italy          141             52
# 2  1998        France    France       Brazil          171             64
# 3  2002         Japan    Brazil      Germany          161             64
# 4  2006       Germany     Italy       France          147             64
# 5  2010  South Africa     Spain  Netherlands          145             64
# 6  2014        Brazil   Germany    Argentina          171             64

# %%
d = {'Year':[1990, 1994, 1998, 2002],
     'Country':['Italy', 'USA', 'France', 'Japan'],
     'Winner':['Germany', 'Brazil', 'France','Brazil'],
     'GoalsScored':[115, 141, 171, 161]}
print(d)
pd.DataFrame(d)
# Out:
# {'Year': [1990, 1994, 1998, 2002], 'Country': ['Italy', 'USA', 'France', 'Japan'], 'Winner': ['Germany', 'Brazil', 'France', 'Brazil'], 'GoalsScored': [115, 141, 171, 161]}
#    Year Country   Winner  GoalsScored
# 0  1990   Italy  Germany          115
# 1  1994     USA   Brazil          141
# 2  1998  France   France          171
# 3  2002   Japan   Brazil          161

# %%
df_lodict = [
             {'year' : 2002, 'HostCountry' : 'Japan', 'Winner' : 'Brazil'},
             {'year' : 2006, 'HostCountry' : 'Germany', 'Winner' : 'Italy'},
             {'year' : 2010, 'HostCountry' : 'South Africa', 'Winner' : 'Spain'},
             {'year' : 2014, 'HostCountry' : 'Brazil', 'Winner' : 'Germany'},
            ]
pd.DataFrame(df_lodict)
# Out:
#     HostCountry   Winner  year
# 0         Japan   Brazil  2002
# 1       Germany    Italy  2006
# 2  South Africa    Spain  2010
# 3        Brazil  Germany  2014

# %%
df_lotuples = [(2002, 'Japan', 'Brazil', 161), 
                (2006, 'Germany', 'Italy', 147), 
                (2010, 'South Africa', 'Spain', 145),
                (2014, 'Brazil', 'Germany', 171)
              ]
pd.DataFrame(df_lotuples, columns = ['Year', 'Country', 'Winner', 'Goals_Scored'])
# Out:
#    Year       Country   Winner  Goals_Scored
# 0  2002         Japan   Brazil           161
# 1  2006       Germany    Italy           147
# 2  2010  South Africa    Spain           145
# 3  2014        Brazil  Germany           171

# %% [markdown]
# # Selection and indexing

# %%
bike_data = pd.read_csv('datasets/citibike_tripdata.csv')
bike_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
bike_data.tail()
# Out:
#        tripduration            starttime             stoptime  \
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32423              3184          Paulus Hook            3279      Dixon Mills
# 32424              3202         Newport PATH            3639       Harborside
# 32425              3220    5 Corners Library            3195          Sip Ave
# 32426              3281  Leonard Gordon Park            3213   Van Vorst Park
# 32427              3220    5 Corners Library            3207      Oakland Ave
#
#        bikeid              name_localizedValue    usertype
# 32423   29639  Join Citi Bike for $14.95/month  Subscriber
# ...

# %%
bike_data['end station name'].head()
# Out:
# 0     Newport Pkwy
# 1        City Hall
# 2     Lincoln Park
# 3    Grove St PATH
# 4          Sip Ave
# Name: end station name, dtype: object

# %%
bike_data[['start station name','end station name']].head()
# bike_data[['start station name','end station name']]
# Out:
#   start station name end station name
# 0         Harborside     Newport Pkwy
# 1           Grand St        City Hall
# 2    McGinley Square     Lincoln Park
# 3          City Hall    Grove St PATH
# 4        Oakland Ave          Sip Ave

# %%
bike_data.head()
bike_data['start station id'][1]
# Out:
# 3681

# %%
# at attribute - row and column
# bike_data.at[1, 'start station name']

# %%
bike_data['start station id'][1] = 36810
bike_data.head()
# Out:
# /Users/vigneshkarthick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53             36810
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# ...

# %%
new_bike_data = bike_data[:7]
new_bike_data.index = ['bike'+str(i) for i in range(1,8)]
new_bike_data
# Out:
#        tripduration            starttime             stoptime  \
# bike1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# bike2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# bike3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# bike4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# bike5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# bike6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# bike7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
#
#        start station id     start station name  end station id  \
# bike1              3639             Harborside            3199
# bike2             36810               Grand St            3185
# bike3              3194        McGinley Square            3193
# bike4              3185              City Hall            3186
# bike5              3207            Oakland Ave            3195
# bike6              3194        McGinley Square            3195
# ...

# %%
# bike_data

# %%
new_bike_data.loc['bike1']
# Out:
# tripduration                           338
# starttime              2018-05-01 00:04:47
# stoptime               2018-05-01 00:10:25
# start station id                      3639
# start station name              Harborside
# end station id                        3199
# end station name              Newport Pkwy
# bikeid                               33558
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: bike1, dtype: object

# %%
new_bike_data.loc['bike2':'bike4']
# Out:
#        tripduration            starttime             stoptime  \
# bike2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# bike3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# bike4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# bike2             36810           Grand St            3185        City Hall
# bike3              3194    McGinley Square            3193     Lincoln Park
# bike4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# bike2   33593                                  24 Hour    Customer
# bike3   29217  FREE Bonus Month with Annual Membership  Subscriber
# bike4   29662                                  24 Hour    Customer

# %%
new_bike_data.iloc[1:4, 0:8]
# Out:
#        tripduration            starttime             stoptime  \
# bike2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# bike3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# bike4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# bike2             36810           Grand St            3185        City Hall
# bike3              3194    McGinley Square            3193     Lincoln Park
# bike4              3185          City Hall            3186    Grove St PATH
#
#        bikeid
# bike2   33593
# bike3   29217
# bike4   29662

# %%
new_bike_data.loc['bike2':'bike4', 'tripduration':'bikeid']
# Out:
#        tripduration            starttime             stoptime  \
# bike2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# bike3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# bike4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# bike2             36810           Grand St            3185        City Hall
# bike3              3194    McGinley Square            3193     Lincoln Park
# bike4              3185          City Hall            3186    Grove St PATH
#
#        bikeid
# bike2   33593
# bike3   29217
# bike4   29662

# %%
bike_data[(bike_data['tripduration']>20000) & (bike_data['usertype']=='Subscriber')]
# Out:
#        tripduration            starttime             stoptime  \
# 381           25958  2018-05-01 09:29:09  2018-05-01 16:41:48
# 544           21110  2018-05-01 13:40:03  2018-05-01 19:31:53
# 11529        608122  2018-05-10 10:32:11  2018-05-17 11:27:34
# 16166         21932  2018-05-15 08:23:58  2018-05-15 14:29:30
# 16207         54897  2018-05-15 08:36:31  2018-05-15 23:51:28
# 17695         39304  2018-05-16 21:35:38  2018-05-17 08:30:43
# 24888         55351  2018-05-23 19:40:18  2018-05-24 11:02:49
# 27513         83360  2018-05-25 16:40:29  2018-05-26 15:49:50
# 28028         33282  2018-05-26 02:52:58  2018-05-26 12:07:41
# 28301         23203  2018-05-26 12:00:24  2018-05-26 18:27:08
# 29544        173196  2018-05-28 11:38:43  2018-05-30 11:45:20
# 30282         39935  2018-05-28 21:14:39  2018-05-29 08:20:14
# 31774         22675  2018-05-30 01:44:51  2018-05-30 08:02:46
#
#        start station id start station name  end station id  \
# ...

# %%
# bike_data['tripduration']>20000

# %%
bike_data[(bike_data['tripduration']>20000) | (bike_data['usertype']=='Subscriber')]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# 7               830  2018-05-01 05:11:50  2018-05-01 05:25:41
# 8               395  2018-05-01 05:12:07  2018-05-01 05:18:42
# 9               170  2018-05-01 05:13:52  2018-05-01 05:16:43
# 10              353  2018-05-01 05:18:36  2018-05-01 05:24:29
# 11              704  2018-05-01 05:23:26  2018-05-01 05:35:11
# 12              265  2018-05-01 05:23:32  2018-05-01 05:27:58
# 13              428  2018-05-01 05:31:40  2018-05-01 05:38:48
# 14              473  2018-05-01 05:34:23  2018-05-01 05:42:16
# 15              178  2018-05-01 05:34:30  2018-05-01 05:37:28
# ...
